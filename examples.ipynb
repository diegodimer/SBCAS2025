# %%
from sbcasdiego.Datasets import HeartDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sbcasdiego.Datasets import HeartDataset
#
# File ~/dev/pessoal/SBCAS2025/sbcasdiego/Datasets/HeartDataset.py:2
#       1 import pandas as pd
# ----> 2 from sbcasdiego.Datasets.BaseDataset import BaseDataset
#       5 class HeartDataset(BaseDataset):
#       6     """
#       7     HeartDataset class for handling heart disease dataset.
#       8     This class inherits from BaseDataset and is used to manage and preprocess the heart disease dataset.
#    (...)
#      17
#      18     """
#
# File ~/dev/pessoal/SBCAS2025/sbcasdiego/Datasets/BaseDataset.py:8
#       6 import matplotlib.pyplot as plt
#       7 import numpy as np
# ----> 8 from PreTrainingBias.PreTrainingBias import PreTrainingBias
#       9 from sklearn import tree
#      10 from sklearn.ensemble import RandomForestClassifier
#
# ...

# %%
h = HeartDataset()
h.num_repetitions = 0
print(h)
# h.execute_models()
